# %%
import pandas as pd

# %%
cards = pd.read_csv('../cards.txt')

# %%
cards
# Out:
#        id                   name  \
# 0       7     Garrosh Hellscream
# 1       8           Mind Control
# 2       9          Prophet Velen
# 3      12            Mana Addict
# 4      21                 Barrel
# 5      22             Inner Rage
# 6      23           Bane of Doom
# 7      28         Kor'kron Elite
# 8      30           Thoughtsteal
# 9      31                 Rexxar
# 10     32   Al'Akir the Windlord
# 11     34    Silvermoon Guardian
# 12     36               Cenarius
# 13     37    Pint-Sized Summoner
# 14     41        Frostwolf Grunt
# 15     45         Tauren Warrior
# 16     48             Voidwalker
# 17     51               Windfury
# 18     52        Emboldener 3000
# 19     54                  Whelp
# 20     59  Mechanical Dragonling
# 21     60       Summon a Panther
# 22     61         Spiteful Smith
# 23     63               Cat Form
# 24     64                  Swipe
# 25     67   Silverback Patriarch
# 26     68    Stranglethorn Tiger
# ...

# %%
len(cards)
# Out:
# 517

# %%
len(cards[cards.collectible])
# Out:
# 399

# %%
collectibles = cards[cards.collectible]

# %%
collectibles
# Out:
#        id                  name  \
# 0       7    Garrosh Hellscream
# 1       8          Mind Control
# 2       9         Prophet Velen
# 3      12           Mana Addict
# 5      22            Inner Rage
# 6      23          Bane of Doom
# 7      28        Kor'kron Elite
# 8      30          Thoughtsteal
# 9      31                Rexxar
# 10     32  Al'Akir the Windlord
# 11     34   Silvermoon Guardian
# 12     36              Cenarius
# 13     37   Pint-Sized Summoner
# 14     41       Frostwolf Grunt
# 15     45        Tauren Warrior
# 16     48            Voidwalker
# 17     51              Windfury
# 22     61        Spiteful Smith
# 24     64                 Swipe
# 25     67  Silverback Patriarch
# 26     68   Stranglethorn Tiger
# 27     69    Silver Hand Knight
# 28     70     Blessing of Might
# 29     75                 Brawl
# 31     77             Polymorph
# 32     86              Starfall
# 33     90        Chillwind Yeti
# 34     95               Nourish
# ...

# %%
cards[cards.health.apply(lambda x: 0 if x=='null' else int(x))>10]
# Out:
#        id                 name  \
# 0       7   Garrosh Hellscream
# 9      31               Rexxar
# 91    274  Malfurion Stormrage
# 156   436              Malygos
# 187   492        Lord Jaraxxus
# 243   637     Jaina Proudmoore
# 254   671   Uther Lightbringer
# 293   777        Lord Jaraxxus
# 309   813         Anduin Wrynn
# 315   834            Deathwing
# 335   893              Gul'dan
# 349   930    Valeera Sanguinar
# 392  1066               Thrall
# 432  1186                Ysera
# 445  1325     Jaina Proudmoore
# 459  1382  Millhouse Manastorm
# 461  1481           King Mukla
# 465  1602     Hemet Nesingwary
# 471  1636    Illidan Stormrage
# 491  1667       Lorewalker Cho
#
#                                            description  \
# 0                                                  NaN
# 9                                                  NaN
# 91                                                 NaN
# 156                             <b>Spell Damage</b> +5
# ...

# %%
cards.health.apply(lambda x: 0 if x=='null' else int(x))
# Out:
# 0      30
# 1       0
# 2       7
# 3       3
# 4       2
# 5       0
# 6       0
# 7       3
# 8       0
# 9      30
# 10      5
# 11      3
# 12      8
# 13      2
# 14      2
# 15      3
# 16      3
# 17      0
# 18      4
# 19      1
# 20      1
# 21      0
# 22      6
# 23      0
# 24      0
# 25      4
# 26      5
# 27      4
# 28      0
# 29      0
#        ..
# 487     3
# 488     8
# 489     3
# 490     2
# 491    25
# 492     1
# 493     2
# 494     0
# 495     4
# 496     0
# 497     2
# 498     4
# 499     6
# 500     0
# 501     7
# 502     5
# 503     1
# 504     5
# 505     0
# 506     2
# 507     1
# 508     5
# 509     1
# 510     0
# 511     3
# 512     1
# 513     3
# 514     0
# 515     0
# 516     1
# Name: health, dtype: int64
